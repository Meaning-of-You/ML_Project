# %% [markdown]
# # pymysql
# - mysql을 python에서 사용할 수 있는 라이브러리
# - 코드 작성 순서
#     - pymysql 모듈 import
#     - pymysql.connect() 메소드를 사용하여 연결
#     - cursor() 메소드를 호출해서 가져옴
#     - fetchall(), fetchone(), fetchmany() 메소드로 코드에서 활용
#     - DML 문장 실행 후 commit() 메소드로 데이터 확정
#     - close() 메소드로 DB 연결 닫음

# %% [markdown]
# ### 데이터베이스 연동하기

# %%
# pymysql 설치
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/4f/52/a115fe175028b058df353c5a3d5290b71514a83f67078a6482cff24d6137/PyMySQL-1.0.2-py3-none-any.whl (43kB)
#     100% |████████████████████████████████| 51kB 1.7MB/s ta 0:00:01
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# You are using pip version 10.0.1, however version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# You should consider upgrading via the 'pip install --upgrade pip' command.
! pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/ca/31/b88ef447d595963c01060998cb329251648acf4a067721b0452c45527eb8/pip-21.2.4-py3-none-any.whl (1.6MB)
#     100% |████████████████████████████████| 1.6MB 14.0MB/s ta 0:00:01  7% |██▌                             | 122kB 1.6MB/s eta 0:00:01
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-21.2.4

# %%
# pymysql import 
import pymysql

# %%
# mysql 연결
conn = pymysql.connect(host = '3.38.70.165', # DB IP (local에 접속하는 경우 : localhost)
                     port = 3306, # 포트 번호
                     user = 'min',
                     passwd = 'yumin!', # mySQL 접속 계정 패스워드
                     db = 'movie', # 데이터베이스명
                     charset='utf8') # 한글 깨짐 방지

# %%
# 데이터베이스 연결 확인
conn

# %%
# DB 조회 결과를 dictionary로 저장
curs = conn.cursor(pymysql.cursors.DictCursor)

# %% [markdown]
# ### CSV 파일 불러오기

# %%
# pandas 라이브러리 import 
import pandas as pd

# Data/movies_train 파일과 Data/movies_test 파일 불러오기
movie_tr = pd.read_csv('./Data/movies_train.csv')
movie_te = pd.read_csv('./Data/movies_test.csv')

# %%
# head(3): 상위 3개의 데이터 행만 확인
movie_tr.head(3)
# Out:
#        title distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁    롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들      (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게      (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1      1161602.50             2        387          3      7072501
# 2       220775.25             4        343          4      6959083

# %%
movie_te.head(3)
# Out:
#          title distributor   genre release_time  time screening_rat director  \
# 0       용서는 없다      시네마서비스     느와르   2010-01-07   125      청소년 관람불가      김형준
# 1  아빠가 여자를 좋아해      (주)쇼박스  멜로/로맨스   2010-01-14   113       12세 관람가      이광재
# 2          하모니   CJ 엔터테인먼트     드라마   2010-01-28   115       12세 관람가      강대규
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# 0    3.005290e+05             2        304          3
# 1    3.427002e+05             4        275          3
# 2    4.206611e+06             3        419          7

# %% [markdown]
# - movies_train과 movies_test는 **box_off_num** 컬럼 유무의 차이

# %% [markdown]
# ### 테이블 생성하기
# - sql문 직접 입력하기 vs 테이블 자동 생성 쿼리 사용하기
# - 컬럼
#     - `title` : 영화의 제목
#     - `distributor` : 배급사
#     - `genre` : 장르
#     - `release_time` : 개봉일
#     - `time` : 상영시간(분)
#     - `screening_rat` : 상영등급
#     - `director` : 감독이름
#     - `dir_prev_bfnum` : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
#     - `dir_prev_num` : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)
#     - `num_staff` : 스텝수
#     - `num_actor` : 주연배우수
#     - `box_off_num` : 관객수

# %%
# sql문 직접 입력하기
# 일련번호가 없기 때문에 영화 제목을 기본키로 지정
sql = '''
CREATE TABLE movie ( 
    title varchar(50) not null comment '영화명' primary key, 
    distributor varchar(50) null comment '배급사', 
    genre varchar(10) null comment '장르',
    release_time date null comment '개봉일',
    time int null comment '상영시간(분)',
    screening_rat varchar(10) null comment '상영등급',
    director varchar(10) null comment '감독명',
    dir_prev_bfnum float null comment '감독 평균 관객수',
    dir_prev_num int null comment '감독 영화 개수',
    num_staff int null comment '스텝수',
    num_actor int null comment '주연배우수',
    box_off_num int null comment '관객수'
) 
''' 
curs.execute(sql)
# Out:
# 0

# %% [markdown]
# ### 데이터 삽입하기
# - sqlalchemy 사용

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

# create_engint("mysql+pymysql://사용자명:"+"패스워드"+"@IP 주소:포트번호/DB 이름?charset=utf8", encoding ='utf-8')
engine = create_engine("mysql+pymysql://min:"+"yumin!"+"@3.38.70.165:3306/movie?charset=utf8", encoding ='utf-8')

# %%
# engine 연결
conn = engine.connect()

# %% [markdown]
# - train 데이터 삽입

# %%
# to_sql(name=테이블명, con=engine, if_exists='옵션', index=False)
# 옵션: append(기존 테이블에 데이터 추가), fail(기존 테이블이 있으면 아무것도 하지 않음), replace(기존 테이블 삭제후 새로 생성)
movie_tr.to_sql(name='movie', con=engine, if_exists='append', index=False)

# %%
# 연결 종료
conn.close()

# %% [markdown]
# ### 데이터 불러오기

# %%
# movie 데이터 조회
sql = '''
SELECT * FROM movie
''' 
curs.execute(sql)
# Out:
# 600

# %%
# 데이터 조회 결과를 result에 저장
result = curs.fetchall()
    
print(result[0])
# Out:
# {'title': '              개를 훔치는 완벽한 방법', 'distributor': '리틀빅픽처스', 'genre': '드라마', 'release_time': datetime.date(2014, 12, 31), 'time': 109, 'screening_rat': '전체 관람가', 'director': '김성호', 'dir_prev_bfnum': 495535.0, 'dir_prev_num': 1, 'num_staff': 292, 'num_actor': 8, 'box_off_num': 306642}

# %%
# 데이터 프레임으로 result 결과 저장
df = pd.DataFrame(result)
print(df.columns) # columns
print(df.head())
# Out:
# Index(['box_off_num', 'dir_prev_bfnum', 'dir_prev_num', 'director',
#        'distributor', 'genre', 'num_actor', 'num_staff', 'release_time',
#        'screening_rat', 'time', 'title'],
#       dtype='object')
#    box_off_num  dir_prev_bfnum  dir_prev_num director      distributor genre  \
# 0       306642        495535.0             1      김성호           리틀빅픽처스   드라마
# 1         4778             NaN             0      정성복  유니버설픽쳐스인터내셔널코리아   뮤지컬
# 2         1124         35348.0             1      한윤선              어뮤즈   느와르
# 3         3404             NaN             0      김태곤            인디스토리   드라마
# 4      2963652       2636380.0             1      조근현            인벤트 디    액션
#
#    num_actor  num_staff release_time screening_rat  time  \
# 0          8        292   2014-12-31        전체 관람가   109
# 1          5          3   2014-09-18        전체 관람가   129
# 2          3        126   2014-08-14      청소년 관람불가   104
# 3          4         32   2013-02-21       15세 관람가    85
# 4          3        365   2012-11-29       15세 관람가   135
#
#                          title
# 0                개를 훔치는 완벽한 방법
# 1              1789, 바스티유의 연인들
# 2              18: 우리들의 성장 느와르
# 3                     1999, 면회
# 4                          26년

# %%
df
# Out:
#      box_off_num  dir_prev_bfnum  dir_prev_num director      distributor  \
# 0         306642      495535.000             1      김성호           리틀빅픽처스
# 1           4778             NaN             0      정성복  유니버설픽쳐스인터내셔널코리아
# 2           1124       35348.000             1      한윤선              어뮤즈
# 3           3404             NaN             0      김태곤            인디스토리
# 4        2963652     2636380.000             1      조근현            인벤트 디
# 5          13886       57943.000             1      민백두        CJ 엔터테인먼트
# 6          96080     1198420.000             2      이근우         필라멘트 픽쳐스
# 7         104736      107376.000             2      김익로        CJ 엔터테인먼트
# 8             79             NaN             0      박성미           인터콘미디어
# 9          21483             NaN             0      박사유            인디스토리
# 10       2242510     3640580.000             2      김지훈      CJ E&M 영화부문
# 11      12811435      819050.000             2      이환경           (주)NEW
# 12           742             NaN             0      진승현  동국대학교 충무로영상제작센터
# 13            42             NaN             0      박선욱          사람과 사람들
# 14           745             NaN             0   조조 히데오        (주) 케이알씨지
# 15         74261     1648550.000             3      라희찬              시너지
# 16       1201944             NaN             0      김동원            주머니필름
# 17          1240             NaN             0      공귀현            인디스토리
# 18        270602      627302.000             3      장윤현           시네마서비스
# 19        142170             NaN             0      김태균            인벤트 디
# 20          1759             NaN             0      이돈구            인디스토리
# 21          1533             NaN             0      김봉은             드림로드
# 22          3534             NaN             0      김봉은        에이블엔터테인먼트
# 23       1310895     1012310.000             1      우민호         롯데엔터테인먼트
# 24           555             NaN             0      김대성            마법사필름
# 25       3117859          72.500             2      김성수     (주)아이필름코퍼레이션
# 26       5508299       80741.000             2      조의석           (주)NEW
# 27       2192276     1949110.000             4       유하           (주)쇼박스
# 28        233211      837969.000             2      육상효         롯데엔터테인먼트
# 29          1504             NaN             0       황욱            어썸 피플
# ..           ...             ...           ...      ...              ...
# 570           71         345.333             3      전화성        한국YWCA연합회
# 571          400             NaN             0      김민욱        (주) 케이알씨지
# 572        36841             NaN             0      장건재            인디스토리
# 573       257996      462623.000             1      권형진            인벤트 디
# 574         5851      431231.000             1      최종태          (주)키노아이
# 575      1475091        3833.000             1      심성보           (주)NEW
# 576      8666208     1843890.000             3      이석훈         롯데엔터테인먼트
# 577         1068             NaN             0      황석호          마운틴 픽처스
# 578       956103             NaN             0      하정우           (주)NEW
# 579        61414         145.000             1       조운         SBS콘텐츠허브
# 580      3019960     1877000.000             3      김영탁              NEW
# 581        43947     2270050.000             2      박훈정               KT
# 582       431310      120930.000             3      박흥식         롯데엔터테인먼트
# 583         2329             NaN             0  안도 마사히로         머스트 씨 무비
# 584         4586             NaN             0      이정인          타임스토리그룹
# 585          148         427.000             2      남기웅         골든타이드픽처스
# 586       790959             NaN             0       김곡  CJ E&M Pictures
# 587       142609      138190.000             1      임권택           리틀빅픽쳐스
# 588      2436884       43734.000             2      변영주         필라멘트 픽쳐스
# 589          310             NaN             0      방현준          (주)온비즈넷
# 590          303             NaN             0      한우진        (주)유비네트워크
# 591           72      695202.000             2      박용집         골든타이드픽처스
# 592      2260512     5046100.000             1      나홍진           (주)쇼박스
# 593       155281             NaN             0      김종철             스토리셋
# 594      1110523      739522.000             3      임상윤           (주)쇼박스
# 595          938             NaN             0      이홍기            인디플러그
# 596        39916             NaN             0      김봉곤              어뮤즈
# 597          256             NaN             0      임우성          (주)키노아이
# 598         1298       59648.500             2      이홍석          마운틴 픽처스
# 599      7759711     3549470.000             4      이석훈        CJ 엔터테인먼트
#
#       genre  num_actor  num_staff release_time screening_rat  time  \
# 0       드라마          8        292   2014-12-31        전체 관람가   109
# 1       뮤지컬          5          3   2014-09-18        전체 관람가   129
# 2       느와르          3        126   2014-08-14      청소년 관람불가   104
# 3       드라마          4         32   2013-02-21       15세 관람가    85
# 4        액션          3        365   2012-11-29       15세 관람가   135
# 5       드라마          4         78   2013-07-04       15세 관람가    97
# 6       코미디          2        150   2012-08-30       15세 관람가    99
# 7       코미디          3        157   2012-07-19       15세 관람가   107
# 8     다큐멘터리          0         10   2010-06-24        전체 관람가    63
# 9     다큐멘터리          5         37   2014-09-18       12세 관람가   106
# 10       SF          5         59   2011-08-04       15세 관람가   112
# 11      코미디          8        300   2013-01-23       15세 관람가   127
# 12      드라마          4         10   2010-04-22      청소년 관람불가    96
# 13       공포          2         55   2012-08-23      청소년 관람불가    94
# 14   멜로/로맨스          4          0   2015-07-27      청소년 관람불가    89
# 15      드라마          3        485   2011-11-03       12세 관람가   114
# 16       액션          7        477   2012-08-15       15세 관람가   113
# 17      드라마          4         70   2012-05-24      청소년 관람불가    91
# 18     미스터리          4         95   2012-03-15       15세 관람가   115
# 19     서스펜스          2        207   2014-04-10      청소년 관람불가   117
# 20      드라마          2         21   2013-08-22      청소년 관람불가   103
# 21   멜로/로맨스          2         26   2014-10-08      청소년 관람불가    85
# 22   멜로/로맨스          4         27   2014-04-10      청소년 관람불가    87
# 23      드라마          5        372   2012-09-20       15세 관람가   115
# 24       공포          2          1   2015-12-03      청소년 관람불가    91
# 25      드라마          3        458   2013-08-14       15세 관람가   121
# 26      느와르          3        331   2013-07-03       15세 관람가   119
# 27       액션          3        719   2015-01-21      청소년 관람불가   135
# 28      코미디          4        262   2012-10-25       15세 관람가   113
# 29      느와르          5         58   2015-03-05      청소년 관람불가   101
# ..      ...        ...        ...          ...           ...   ...
# 570   다큐멘터리          6          2   2014-12-10        전체 관람가    61
# 571  멜로/로맨스          1          0   2015-11-25      청소년 관람불가    89
# 572     드라마          3          7   2015-06-11        전체 관람가    97
# 573      공포          4        156   2015-09-10      청소년 관람불가    96
# 574     드라마          2         14   2012-03-22       12세 관람가   113
# 575     드라마          7        510   2014-08-13      청소년 관람불가   111
# 576      SF          2        868   2014-08-06       12세 관람가   130
# 577   다큐멘터리          2          3   2010-02-25        전체 관람가    76
# 578     드라마          2        412   2015-01-14       12세 관람가   124
# 579      액션          3        290   2011-05-26      청소년 관람불가   100
# 580     코미디          6        369   2010-12-22       12세 관람가   111
# 581      액션          3        306   2011-02-24       15세 관람가   111
# 582      액션          3        439   2015-08-13       15세 관람가   121
# 583   애니메이션          3          8   2014-07-17       12세 관람가    67
# 584   애니메이션          5          2   2011-08-18        전체 관람가    85
# 585     드라마          2         80   2015-01-29      청소년 관람불가    72
# 586      공포          5         98   2011-06-09       15세 관람가   106
# 587     드라마          3        309   2015-04-09      청소년 관람불가    94
# 588    미스터리          3        308   2012-03-08       15세 관람가   117
# 589      공포          3         12   2014-03-14      청소년 관람불가    90
# 590     코미디          7          7   2015-10-08      청소년 관람불가    83
# 591     코미디          3        140   2014-10-16        전체 관람가    87
# 592     느와르          3        683   2010-12-22      청소년 관람불가   156
# 593   다큐멘터리          1         54   2010-01-14       12세 관람가    94
# 594      액션          2        342   2012-10-11      청소년 관람불가    96
# 595   다큐멘터리          1          4   2015-04-09        전체 관람가    70
# 596   다큐멘터리          1          0   2011-10-27        전체 관람가    92
# 597     드라마          2         17   2011-10-13       15세 관람가    65
# 598   다큐멘터리          2          1   2010-10-07        전체 관람가    85
# 599     드라마          2        520   2015-12-16       12세 관람가   124
#
#                            title
# 0                  개를 훔치는 완벽한 방법
# 1                1789, 바스티유의 연인들
# 2                18: 우리들의 성장 느와르
# 3                       1999, 면회
# 4                            26년
# 5                           48미터
# 6                       577 프로젝트
# 7                      5백만불의 사나이
# 8                     60년전, 사선에서
# 9                      60만번의 트라이
# 10                           7광구
# 11                       7번방의 선물
# 12                        7월 32일
# 13                           90분
# 14                        AV 아이돌
# 15                        Mr.아이돌
# 16                   R2B: 리턴투베이스
# 17                        U.F.O.
# 18                            가비
# 19                            가시
# 20                           가시꽃
# 21                    가자, 장미여관으로
# 22             가자! 장미여관으로 2 - 갈증
# 23                            간첩
# 24                        감금의 시간
# 25                            감기
# 26                          감시자들
# 27                       강남 1970
# 28                강철대오 : 구국의 철가방
# 29                개: dog eat dog
# ..                           ...
# 570                  한민족 그리고 조선족
# 571                    한양 기방 춘향뎐
# 572                    한여름의 판타지아
# 573                           함정
# 574                           해로
# 575                           해무
# 576                 해적: 바다로 간 산적
# 577                      행복한 울릉인
# 578                          허삼관
# 579                           헤드
# 580                      헬로우 고스트
# 581                           혈투
# 582                    협녀, 칼의 기억
# 583                      홈 스위트 홈
# 584                     홍길동 2084
# 585         화끈한 써비스: 어느 잔인한 미용사의
# 586                 화이트: 저주의 멜로디
# 587                           화장
# 588                           화차
# 589                      화창한 그날들
# 590           환타스틱 러브짐: 전쟁 같은 사랑
# 591                           황구
# 592                           황해
# 593                           회복
# 594                          회사원
# 595                     후쿠시마의 미래
# 596                      훈장과 악동들
# 597                           흉터
# 598               희망의 별 - 이퀘지레템바
# 599                         히말라야
#
# [600 rows x 12 columns]

# %% [markdown]
# ### 문제점
# - 데이터를 불러왔을 때 역순으로 저장
